# %% [markdown]
# <a href="https://colab.research.google.com/github/CleberSalustiano/AI_IFES/blob/main/Pandas_Python_Exercicios/exercicios_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Resolução de exercícios gerados pelo ChatGPT.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Exercício 1

# %%
df = pd.read_csv("dados.csv")
print(df.shape)
df.head()
# Out:
# (99, 6)
#    produto_id nome_produto  preco_unitario  quantidade_vendida  data_venda  \
# 0           1    Produto A           10.50                  25  2023-08-01
# 1           2    Produto B           15.25                  17  2023-08-02
# 2           3    Produto C            5.80                  32  2023-08-03
# 3           1    Produto A           10.50                  12  2023-08-03
# 4           4    Produto D           30.00                   5  2023-08-04
#
#            cidade
# 0       São Paulo
# 1       São Paulo
# 2  Rio de Janeiro
# 3  Rio de Janeiro
# 4       São Paulo

# %%
df.info
# Out:
# <bound method DataFrame.info of     produto_id nome_produto  preco_unitario  quantidade_vendida  data_venda  \
# 0            1    Produto A           10.50                  25  2023-08-01
# 1            2    Produto B           15.25                  17  2023-08-02
# 2            3    Produto C            5.80                  32  2023-08-03
# 3            1    Produto A           10.50                  12  2023-08-03
# 4            4    Produto D           30.00                   5  2023-08-04
# ..         ...          ...             ...                 ...         ...
# 94           3    Produto C            5.80                  32  2023-08-03
# 95           1    Produto A           10.50                  12  2023-08-03
# 96           4    Produto D           30.00                   5  2023-08-04
# 97           2    Produto B           15.25                   8  2023-08-04
# 98           3    Produto C            5.80                  21  2023-08-05
#
#             cidade
# ...

# %% [markdown]
# Exercício 2

# %%
print(df.isnull().sum())

df["preco_unitario"].fillna(df["preco_unitario"].mean())
df["quantidade_vendida"].fillna(df["quantidade_vendida"].mean())
# Out:
# produto_id            0
# nome_produto          0
# preco_unitario        0
# quantidade_vendida    0
# data_venda            0
# cidade                0
# dtype: int64
# 0     25
# 1     17
# 2     32
# 3     12
# 4      5
#       ..
# 94    32
# 95    12
# 96     5
# 97     8
# 98    21
# Name: quantidade_vendida, Length: 99, dtype: int64

# %%
df["Nova Coluna"] = df["preco_unitario"] + df["quantidade_vendida"]
df
# Out:
#     produto_id nome_produto  preco_unitario  quantidade_vendida  data_venda  \
# 0            1    Produto A           10.50                  25  2023-08-01
# 1            2    Produto B           15.25                  17  2023-08-02
# 2            3    Produto C            5.80                  32  2023-08-03
# 3            1    Produto A           10.50                  12  2023-08-03
# 4            4    Produto D           30.00                   5  2023-08-04
# ..         ...          ...             ...                 ...         ...
# 94           3    Produto C            5.80                  32  2023-08-03
# 95           1    Produto A           10.50                  12  2023-08-03
# 96           4    Produto D           30.00                   5  2023-08-04
# 97           2    Produto B           15.25                   8  2023-08-04
# 98           3    Produto C            5.80                  21  2023-08-05
#
#             cidade  Nova Coluna
# ...

# %%
df_order = df.sort_values(by = "Nova Coluna", ascending=False)
df_order
# Out:
#     produto_id nome_produto  preco_unitario  quantidade_vendida  data_venda  \
# 29           4    Produto D            30.0                  17  2023-08-19
# 59           4    Produto D            30.0                  16  2023-09-06
# 39           4    Produto D            30.0                  15  2023-08-25
# 79           4    Produto D            30.0                  14  2023-09-18
# 24           4    Produto D            30.0                  13  2023-08-16
# ..         ...          ...             ...                 ...         ...
# 38           5    Produto E             8.9                   8  2023-08-25
# 52           1    Produto A            10.5                   6  2023-09-02
# 13           5    Produto E             8.9                   7  2023-08-10
# 28           5    Produto E             8.9                   6  2023-08-19
# 21           3    Produto C             5.8                   9  2023-08-14
#
#             cidade  Nova Coluna
# ...

# %%
df = df.rename(columns={"nome_produto": "produto", "preco_unitario": "preco",
                        "quantidade_vendida": "quantidade", "Nova Coluna": "preco_quantidade"})
df
# Out:
#     produto_id    produto  preco  quantidade  data_venda          cidade  \
# 0            1  Produto A  10.50          25  2023-08-01       São Paulo
# 1            2  Produto B  15.25          17  2023-08-02       São Paulo
# 2            3  Produto C   5.80          32  2023-08-03  Rio de Janeiro
# 3            1  Produto A  10.50          12  2023-08-03  Rio de Janeiro
# 4            4  Produto D  30.00           5  2023-08-04       São Paulo
# ..         ...        ...    ...         ...         ...             ...
# 94           3  Produto C   5.80          32  2023-08-03  Rio de Janeiro
# 95           1  Produto A  10.50          12  2023-08-03  Rio de Janeiro
# 96           4  Produto D  30.00           5  2023-08-04       São Paulo
# 97           2  Produto B  15.25           8  2023-08-04       São Paulo
# 98           3  Produto C   5.80          21  2023-08-05  Rio de Janeiro
#
#     preco_quantidade
# 0              35.50
# 1              32.25
# 2              37.80
# ...

# %% [markdown]
# Exercício 3

# %%
filtro = df["quantidade"] > 10
df_filtrado = df[filtro]
df_filtrado = df_filtrado.sort_values(by = "quantidade", ascending=True)
df_filtrado
# Out:
#     produto_id    produto  preco  quantidade  data_venda          cidade  \
# 17           1  Produto A  10.50          11  2023-08-12       São Paulo
# 25           2  Produto B  15.25          11  2023-08-17  Rio de Janeiro
# 74           4  Produto D  30.00          11  2023-09-15       São Paulo
# 63           5  Produto E   8.90          11  2023-09-09  Rio de Janeiro
# 33           5  Produto E   8.90          11  2023-08-22  Rio de Janeiro
# ..         ...        ...    ...         ...         ...             ...
# 11           3  Produto C   5.80          28  2023-08-08       São Paulo
# 66           3  Produto C   5.80          29  2023-09-10  Rio de Janeiro
# 26           3  Produto C   5.80          30  2023-08-17  Rio de Janeiro
# 94           3  Produto C   5.80          32  2023-08-03  Rio de Janeiro
# 2            3  Produto C   5.80          32  2023-08-03  Rio de Janeiro
#
#     preco_quantidade
# 17             21.50
# 25             26.25
# 74             41.00
# ...

# %%
df[["produto", "quantidade", "produto"]]
# Out:
#       produto  quantidade    produto
# 0   Produto A          25  Produto A
# 1   Produto B          17  Produto B
# 2   Produto C          32  Produto C
# 3   Produto A          12  Produto A
# 4   Produto D           5  Produto D
# ..        ...         ...        ...
# 94  Produto C          32  Produto C
# 95  Produto A          12  Produto A
# 96  Produto D           5  Produto D
# 97  Produto B           8  Produto B
# 98  Produto C          21  Produto C
#
# [99 rows x 3 columns]

# %%
# Como fazer um filtro de uma coluna de um dataframe por uma letra existente.
filtro = df["produto"].str.contains("A")
df_filtrado = df[filtro]
df_filtrado
# Out:
#     produto_id    produto  preco  quantidade  data_venda          cidade  \
# 0            1  Produto A   10.5          25  2023-08-01       São Paulo
# 3            1  Produto A   10.5          12  2023-08-03  Rio de Janeiro
# 7            1  Produto A   10.5          19  2023-08-06       São Paulo
# 12           1  Produto A   10.5          14  2023-08-09  Rio de Janeiro
# 17           1  Produto A   10.5          11  2023-08-12       São Paulo
# 22           1  Produto A   10.5          22  2023-08-15       São Paulo
# 27           1  Produto A   10.5           8  2023-08-18       São Paulo
# 32           1  Produto A   10.5          16  2023-08-21       São Paulo
# 37           1  Produto A   10.5           9  2023-08-24  Rio de Janeiro
# 42           1  Produto A   10.5          20  2023-08-27  Rio de Janeiro
# 47           1  Produto A   10.5          18  2023-08-30  Rio de Janeiro
# 52           1  Produto A   10.5           6  2023-09-02       São Paulo
# ...

# %%
# Filtro a partir de query
df_filtrado = df.query("quantidade > 10 & quantidade < 30 & produto.str.contains('A')")
df_filtrado
# Out:
#     produto_id    produto  preco  quantidade  data_venda          cidade  \
# 0            1  Produto A   10.5          25  2023-08-01       São Paulo
# 3            1  Produto A   10.5          12  2023-08-03  Rio de Janeiro
# 7            1  Produto A   10.5          19  2023-08-06       São Paulo
# 12           1  Produto A   10.5          14  2023-08-09  Rio de Janeiro
# 17           1  Produto A   10.5          11  2023-08-12       São Paulo
# 22           1  Produto A   10.5          22  2023-08-15       São Paulo
# 32           1  Produto A   10.5          16  2023-08-21       São Paulo
# 42           1  Produto A   10.5          20  2023-08-27  Rio de Janeiro
# 47           1  Produto A   10.5          18  2023-08-30  Rio de Janeiro
# 57           1  Produto A   10.5          13  2023-09-05       São Paulo
# 62           1  Produto A   10.5          15  2023-09-08  Rio de Janeiro
# 72           1  Produto A   10.5          24  2023-09-14  Rio de Janeiro
# ...

# %% [markdown]
# Exercício 4

# %%
df_filtrado = df.groupby(["produto"])["quantidade"].mean()
df_filtrado
# Out:
# produto
# Produto A    15.428571
# Produto B    14.238095
# Produto C    21.428571
# Produto D     9.842105
# Produto E    14.117647
# Name: quantidade, dtype: float64

# %% [markdown]
# Exercício 5

# %%
sns.barplot(x="produto", y="quantidade", data=df)
plt.show()
sns.lineplot(x="produto", y="quantidade", data=df)
plt.show()
sns.scatterplot(x="quantidade", y="produto", data=df)
plt.show()

# %% [markdown]
# Exercício 6

# %%
df.to_excel("dados_tratados.xlsx")
